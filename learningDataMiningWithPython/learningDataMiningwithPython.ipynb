# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.arange(10)
plt.plot(data)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
fig, axes = plt.subplots(2, 3)

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000025B6B3A64C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B6B40AC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B6B449488>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025B6B4886C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B6B4CB808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025B6B50DC48>]],
#       dtype=object)

# %%
from numpy.random import randn
plt.plot(randn(30).cumsum(), 'k.')

# %%
" ".join("This string\n\r  has    many\t\nspaces".split())
# Out:
# 'This string has many spaces'
